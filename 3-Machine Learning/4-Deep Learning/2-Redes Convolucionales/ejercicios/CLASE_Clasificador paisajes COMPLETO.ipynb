# %% [markdown]
# # Intel Image Classification (CNN - Keras)

# %% [markdown]
# # Import Packages

# %%
import numpy as np
import os
from sklearn.metrics import confusion_matrix
import seaborn as sn; sn.set(font_scale=1.4)
from sklearn.utils import shuffle           
import matplotlib.pyplot as plt             
import cv2                                 
import tensorflow as tf                
from tqdm import tqdm

# %%
class_names = ['mountain', 'street', 'glacier', 'buildings', 'sea', 'forest']
class_names_label = {class_name:i for i, class_name in enumerate(class_names)}

nb_classes = len(class_names)

IMAGE_SIZE = (32, 32)

# %%
class_names_label
# Out:
# {'mountain': 0,
#  'street': 1,
#  'glacier': 2,
#  'buildings': 3,
#  'sea': 4,
#  'forest': 5}

# %% [markdown]
# # Loading the Data
# We have to write a load_data function that load the images and the labels from the folder.

# %%
def load_data():
    """
        Load the data:
            - 14,034 images to train the network.
            - 3,000 images to evaluate how accurately the network learned to classify images.
    """
    
    datasets = ['C:/Users/alber/Downloads/Paisajes/seg_train/seg_train',
                'C:/Users/alber/Downloads/Paisajes/seg_test/seg_test']
    output = []
    
    # Iterate through training and test sets
    for dataset in datasets:
        
        images = []
        labels = []
        
        print("Loading {}".format(dataset))
        
        # Iterate through each folder corresponding to a category
        for folder in os.listdir(dataset):
            label = class_names_label[folder]
            
            # Iterate through each image in our folder. tqdm is a widget in output...
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):
                
                # Get the path name of the image
                img_path = os.path.join(os.path.join(dataset, folder), file)
                
                # Open and resize the img
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, IMAGE_SIZE) 
                
                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)
                
        images = np.array(images, dtype = 'float32')
        labels = np.array(labels, dtype = 'int32')   
        
        output.append((images, labels))

    return output

# %%
(train_images, train_labels), (test_images, test_labels) = load_data()
# Out:
# Loading C:/Users/alber/Downloads/Paisajes/seg_train/seg_train
# 100%|██████████| 2191/2191 [00:22<00:00, 98.28it/s]
# 100%|██████████| 2271/2271 [00:25<00:00, 89.95it/s]
# 100%|██████████| 2404/2404 [00:22<00:00, 105.14it/s]
# 100%|██████████| 2512/2512 [00:27<00:00, 90.21it/s]
# 100%|██████████| 2274/2274 [00:28<00:00, 79.85it/s]
# 100%|██████████| 2382/2382 [00:24<00:00, 95.44it/s]
# Loading C:/Users/alber/Downloads/Paisajes/seg_test/seg_test
# 100%|██████████| 437/437 [00:04<00:00, 103.29it/s]
# 100%|██████████| 474/474 [00:05<00:00, 93.70it/s]
# 100%|██████████| 553/553 [00:05<00:00, 97.42it/s]
# 100%|██████████| 525/525 [00:04<00:00, 107.90it/s]
# 100%|██████████| 510/510 [00:04<00:00, 116.11it/s]
# 100%|██████████| 501/501 [00:04<00:00, 110.68it/s]

# %%
train_images, train_labels = shuffle(train_images, train_labels, random_state=42)

# %% [markdown]
# # Let's explore the dataset

# %%
n_train = train_labels.shape[0]
n_test = test_labels.shape[0]

print ("Number of training examples: {}".format(n_train))
print ("Number of testing examples: {}".format(n_test))
print ("Each image is of size: {}".format(IMAGE_SIZE))
# Out:
# Number of training examples: 14034
# Number of testing examples: 3000
# Each image is of size: (32, 32)

# %%
import pandas as pd

_, train_counts = np.unique(train_labels, return_counts=True)
_, test_counts = np.unique(test_labels, return_counts=True)
test_df = pd.DataFrame({'train': train_counts,
                    'test': test_counts}, 
             index=class_names
            )
test_df.plot.bar()
plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %%
plt.pie(test_counts,
        explode=(0, 0, 0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %% [markdown]
# ## Good practice: scale the data

# %%
train_images = train_images / 255.0 
test_images = test_images / 255.0

# %% [markdown]
# ## Visualize the data
# We can display a random image from the training set.

# %%
def display_random_image(class_names, images, labels):
    """
        Display a random image from the images array and its correspond label from the labels array.
    """
    
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{} : '.format(index) + class_names[labels[index]])
    plt.show()

# %%
display_random_image(class_names, train_images, train_labels)

# %% [markdown]
# We can also display the first 25 images from the training set directly with a loop to get a better view

# %%
def display_examples(class_names, images, labels):
    """
        Display 25 images from the images array with its corresponding labels
    """
    
    fig = plt.figure(figsize=(10,10))
    fig.suptitle("Some examples of images of the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()

# %%
display_examples(class_names, train_images, train_labels)

# %% [markdown]
# # Beginner: Simple Model Creation
#
# Steps are:
# 1. Build the model,
# 1. Compile the model,
# 1. Train / fit the data to the model,
# 1. Evaluate the model on the testing set,
# 1. Carry out an error analysis of our model.
#
# We can build an easy model composed of different layers such as:
# * Conv2D: (32 filters of size 3 by 3) The features will be "extracted" from the image.
# * MaxPooling2D: The images get half sized.
# * Flatten: Transforms the format of the images from a 2d-array to a 1d-array of 150 150 3 pixel values.
# * Relu  : given a value x, returns max(x, 0).
# * Softmax: 6 neurons, probability that the image belongs to one of the classes.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (IMAGE_SIZE[0], IMAGE_SIZE[1], 3)), 
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

# %% [markdown]
# Then, we can compile it with some parameters such as:
# * **Optimizer**: adam = RMSProp + Momentum.
# What is Momentum and RMSProp ?
# * Momentum = takes into account past gradient to have a better update.
# * RMSProp = exponentially weighted average of the squares of past gradients.
# * **Loss function**: we use sparse categorical crossentropy for classification, each images belongs to one class only

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# We fit the model to the data from the training set. The neural network will learn by itself the pattern in order to distinguish each category.

# %%
history = model.fit(train_images, train_labels, batch_size=128, epochs=10, validation_split = 0.2)
# Out:
# Epoch 1/10
# 88/88 [==============================] - 13s 138ms/step - loss: 1.2193 - accuracy: 0.5245 - val_loss: 0.9986 - val_accuracy: 0.6152
# Epoch 2/10
# 88/88 [==============================] - 10s 119ms/step - loss: 0.9397 - accuracy: 0.6491 - val_loss: 0.9309 - val_accuracy: 0.6416
# Epoch 3/10
# 88/88 [==============================] - 11s 126ms/step - loss: 0.8391 - accuracy: 0.6920 - val_loss: 0.8493 - val_accuracy: 0.6755
# Epoch 4/10
# 88/88 [==============================] - 13s 144ms/step - loss: 0.7748 - accuracy: 0.7168 - val_loss: 0.8265 - val_accuracy: 0.6829
# Epoch 5/10
# 88/88 [==============================] - 11s 131ms/step - loss: 0.7357 - accuracy: 0.7331 - val_loss: 0.8050 - val_accuracy: 0.6983
# Epoch 6/10
# 88/88 [==============================] - 11s 128ms/step - loss: 0.6926 - accuracy: 0.7514 - val_loss: 0.7327 - val_accuracy: 0.7257
# Epoch 7/10
# 88/88 [==============================] - 11s 124ms/step - loss: 0.6572 - accuracy: 0.7661 - val_loss: 0.6876 - val_accuracy: 0.7492
# Epoch 8/10
# 88/88 [==============================] - 10s 118ms/step - loss: 0.6310 - accuracy: 0.7770 - val_loss: 0.6834 - val_accuracy: 0.7585
# Epoch 9/10
# 88/88 [==============================] - 11s 127ms/step - loss: 0.6135 - accuracy: 0.7798 - val_loss: 0.6715 - val_accuracy: 0.7617
# Epoch 10/10
# 88/88 [==============================] - 10s 118ms/step - loss: 0.5853 - accuracy: 0.7918 - val_loss: 0.6634 - val_accuracy: 0.7570

# %%
def plot_accuracy_loss(history):
    """
        Plot the accuracy and the loss during the training of the nn.
    """
    fig = plt.figure(figsize=(15,10))

    # Plot accuracy
    plt.subplot(221)
    plt.plot(history.history['accuracy'],'bo--', label = "acc")
    plt.plot(history.history['val_accuracy'], 'ro--', label = "val_acc")
    plt.title("train_acc vs val_acc")
    plt.ylabel("accuracy")
    plt.xlabel("epochs")
    plt.legend()

    # Plot loss function
    plt.subplot(222)
    plt.plot(history.history['loss'],'bo--', label = "loss")
    plt.plot(history.history['val_loss'], 'ro--', label = "val_loss")
    plt.title("train_loss vs val_loss")
    plt.ylabel("loss")
    plt.xlabel("epochs")

    plt.legend()
    plt.show()

# %%
plot_accuracy_loss(history)

# %% [markdown]
# We should evaluate the model performance on test set

# %%
test_loss = model.evaluate(test_images, test_labels)
# Out:
# 94/94 [==============================] - 1s 14ms/step - loss: 0.6706 - accuracy: 0.7497

# %%
test_loss
# Out:
# [0.6764287948608398, 0.7516666650772095]

# %% [markdown]
# We see that we achieve 0.76 accuracy on the testing test. We got a slight underfitting :(
#
# Let's see how the classifier is doing on random images.

# %%
predictions = model.predict(test_images)     # Vector of probabilities
pred_labels = np.argmax(predictions, axis = 1) # We take the highest probability

display_random_image(class_names, test_images, pred_labels)
# Out:
# 94/94 [==============================] - 1s 15ms/step

# %% [markdown]
# ## Error analysis
#
# We can try to understand on which kind of images the classifier has trouble.

# %%
def print_mislabeled_images(class_names, test_images, test_labels, pred_labels):
    """
        Print 25 examples of mislabeled images by the classifier, e.g when test_labels != pred_labels
    """
    BOO = (test_labels == pred_labels)
    mislabeled_indices = np.where(BOO == 0)
    mislabeled_images = test_images[mislabeled_indices]
    mislabeled_labels = pred_labels[mislabeled_indices]

    title = "Some examples of mislabeled images by the classifier:"
    display_examples(class_names,  mislabeled_images, mislabeled_labels)

# %%
print_mislabeled_images(class_names, test_images, test_labels, pred_labels)

# %%
CM = confusion_matrix(test_labels, pred_labels)
ax = plt.axes()
sn.heatmap(CM, annot=True, 
           annot_kws={"size": 10}, 
           xticklabels=class_names, 
           yticklabels=class_names, ax = ax)
ax.set_title('Confusion matrix')
plt.show()

# %% [markdown]
# ## Conclusion: The classifier has trouble with 2 kinds of images.
# It has trouble with street and buildings. Well, it can be understandable as as there are buildings in the street.
# It has also trouble with sea, glacier and moutain as well. It is hard for me to fully distinguish them.
# However, it can detects forest very accurately!

# %% [markdown]
# **Intermediate Update January 2020**
#
# * Feature extraction with VGG16 trained on ImageNet
#
#
# * Ensemble models of Neural Networks with the features extracted from VGG
#
# Inspired from: https://machinelearningmastery.com/model-averaging-ensemble-for-deep-learning-neural-networks/
#
# * Fine Tuning with VGG16 trained on ImageNet

# %% [markdown]
# # Feature extraction with VGG ImageNet

# %% [markdown]
# We can extract features from VGG16.

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input

model = VGG16(weights='imagenet', include_top=False)

# %% [markdown]
# Get the features directly from VGG16

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)
# Out:
# 439/439 [==============================] - 91s 207ms/step
# 94/94 [==============================] - 20s 209ms/step

# %% [markdown]
# ## Visualize the features through PCA

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, None, None, 3)]   0
#
#  block1_conv1 (Conv2D)       (None, None, None, 64)    1792
#
#  block1_conv2 (Conv2D)       (None, None, None, 64)    36928
#
#  block1_pool (MaxPooling2D)  (None, None, None, 64)    0
#
#  block2_conv1 (Conv2D)       (None, None, None, 128)   73856
#
#  block2_conv2 (Conv2D)       (None, None, None, 128)   147584
#
#  block2_pool (MaxPooling2D)  (None, None, None, 128)   0
#
#  block3_conv1 (Conv2D)       (None, None, None, 256)   295168
#
#  block3_conv2 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_conv3 (Conv2D)       (None, None, None, 256)   590080
#
#  block3_pool (MaxPooling2D)  (None, None, None, 256)   0
#
#  block4_conv1 (Conv2D)       (None, None, None, 512)   1180160
#
#  block4_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block4_pool (MaxPooling2D)  (None, None, None, 512)   0
#
#  block5_conv1 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv2 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_conv3 (Conv2D)       (None, None, None, 512)   2359808
#
#  block5_pool (MaxPooling2D)  (None, None, None, 512)   0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_features.shape
# Out:
# (14034, 1, 1, 512)

# %%
n_train, x, y, z = train_features.shape
n_test, x, y, z = test_features.shape
numFeatures = x * y * z

# %%
from sklearn import decomposition

pca = decomposition.PCA(n_components = 2)

X = train_features.reshape((n_train, x*y*z))
pca.fit(X)

C = pca.transform(X) # Représentation des individus dans les nouveaux axe
C1 = C[:,0]
C2 = C[:,1]

# %%
### Figures

plt.subplots(figsize=(10,10))

for i, class_name in enumerate(class_names):
    plt.scatter(C1[train_labels == i][:1000], C2[train_labels == i][:1000], label = class_name, alpha=0.4)
plt.legend()
plt.title("PCA Projection")
plt.show()

# %% [markdown]
# We can identifying clusters thanks to this PCA. The clusters correspond more or less to the labels.
#
# We see that glacier and mountain points are very close to each other, as VGG sees them as very similar.
#
# We see that there is no distinction between building and street.

# %% [markdown]
# ## Training on top of VGG
#
# Let's train a simple one-layer Neural Network on the features extracted from VGG.

# %%
from keras.callbacks import EarlyStopping
earlystop = EarlyStopping(patience=20)

# %%
model2 = tf.keras.Sequential([ 
    tf.keras.layers.Flatten(input_shape = (x, y, z)),
    tf.keras.layers.Dense(128, activation=tf.nn.tanh),
    tf.keras.layers.Dense(64, activation=tf.nn.tanh),
    tf.keras.layers.Dense(32, activation=tf.nn.tanh),
    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
])

model2.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001), loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

history2 = model2.fit(train_features, train_labels, batch_size=128, epochs=50, validation_split = 0.2)#, callbacks = [earlystop])
# Out:
# Epoch 1/50
# 88/88 [==============================] - 2s 10ms/step - loss: 0.9924 - accuracy: 0.6370 - val_loss: 0.7900 - val_accuracy: 0.7047
# Epoch 2/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.7245 - accuracy: 0.7309 - val_loss: 0.7261 - val_accuracy: 0.7292
# Epoch 3/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.6690 - accuracy: 0.7551 - val_loss: 0.7165 - val_accuracy: 0.7325
# Epoch 4/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.6410 - accuracy: 0.7666 - val_loss: 0.6697 - val_accuracy: 0.7556
# Epoch 5/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.6229 - accuracy: 0.7705 - val_loss: 0.6832 - val_accuracy: 0.7467
# Epoch 6/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.6012 - accuracy: 0.7758 - val_loss: 0.6631 - val_accuracy: 0.7524
# Epoch 7/50
# 88/88 [==============================] - 1s 10ms/step - loss: 0.5796 - accuracy: 0.7893 - val_loss: 0.6897 - val_accuracy: 0.7467
# Epoch 8/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.5749 - accuracy: 0.7908 - val_loss: 0.6710 - val_accuracy: 0.7560
# Epoch 9/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.5558 - accuracy: 0.7965 - val_loss: 0.6729 - val_accuracy: 0.7510
# Epoch 10/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.5434 - accuracy: 0.7984 - val_loss: 0.6539 - val_accuracy: 0.7617
# Epoch 11/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.5319 - accuracy: 0.8032 - val_loss: 0.6703 - val_accuracy: 0.7553
# Epoch 12/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.5211 - accuracy: 0.8079 - val_loss: 0.6676 - val_accuracy: 0.7517
# Epoch 13/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.5175 - accuracy: 0.8092 - val_loss: 0.6639 - val_accuracy: 0.7588
# Epoch 14/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.4966 - accuracy: 0.8204 - val_loss: 0.7083 - val_accuracy: 0.7503
# Epoch 15/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.4877 - accuracy: 0.8210 - val_loss: 0.6757 - val_accuracy: 0.7613
# Epoch 16/50
# 88/88 [==============================] - 1s 10ms/step - loss: 0.4754 - accuracy: 0.8244 - val_loss: 0.6900 - val_accuracy: 0.7517
# Epoch 17/50
# 88/88 [==============================] - 1s 10ms/step - loss: 0.4682 - accuracy: 0.8281 - val_loss: 0.6997 - val_accuracy: 0.7524
# Epoch 18/50
# 88/88 [==============================] - 1s 10ms/step - loss: 0.4603 - accuracy: 0.8301 - val_loss: 0.6877 - val_accuracy: 0.7549
# Epoch 19/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.4452 - accuracy: 0.8399 - val_loss: 0.6937 - val_accuracy: 0.7499
# Epoch 20/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.4400 - accuracy: 0.8385 - val_loss: 0.6966 - val_accuracy: 0.7606
# Epoch 21/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.4195 - accuracy: 0.8469 - val_loss: 0.6894 - val_accuracy: 0.7556
# Epoch 22/50
# 88/88 [==============================] - 1s 10ms/step - loss: 0.4235 - accuracy: 0.8439 - val_loss: 0.6797 - val_accuracy: 0.7613
# Epoch 23/50
# 88/88 [==============================] - 1s 10ms/step - loss: 0.4019 - accuracy: 0.8529 - val_loss: 0.7223 - val_accuracy: 0.7549
# Epoch 24/50
# 88/88 [==============================] - 1s 11ms/step - loss: 0.3948 - accuracy: 0.8607 - val_loss: 0.7203 - val_accuracy: 0.7553
# Epoch 25/50
# 88/88 [==============================] - 1s 10ms/step - loss: 0.3809 - accuracy: 0.8633 - val_loss: 0.7153 - val_accuracy: 0.7560
# Epoch 26/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.3697 - accuracy: 0.8663 - val_loss: 0.7286 - val_accuracy: 0.7524
# Epoch 27/50
# 88/88 [==============================] - 1s 12ms/step - loss: 0.3656 - accuracy: 0.8691 - val_loss: 0.7302 - val_accuracy: 0.7570
# Epoch 28/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.3484 - accuracy: 0.8743 - val_loss: 0.7531 - val_accuracy: 0.7567
# Epoch 29/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.3402 - accuracy: 0.8785 - val_loss: 0.7680 - val_accuracy: 0.7478
# Epoch 30/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.3352 - accuracy: 0.8781 - val_loss: 0.7599 - val_accuracy: 0.7439
# Epoch 31/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.3117 - accuracy: 0.8901 - val_loss: 0.7602 - val_accuracy: 0.7499
# Epoch 32/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.3029 - accuracy: 0.8937 - val_loss: 0.7546 - val_accuracy: 0.7456
# Epoch 33/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.2902 - accuracy: 0.8989 - val_loss: 0.8090 - val_accuracy: 0.7378
# Epoch 34/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.2799 - accuracy: 0.9033 - val_loss: 0.8189 - val_accuracy: 0.7424
# Epoch 35/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.2746 - accuracy: 0.9026 - val_loss: 0.8054 - val_accuracy: 0.7463
# Epoch 36/50
# 88/88 [==============================] - 1s 7ms/step - loss: 0.2718 - accuracy: 0.9075 - val_loss: 0.8215 - val_accuracy: 0.7460
# Epoch 37/50
# 88/88 [==============================] - 1s 7ms/step - loss: 0.2533 - accuracy: 0.9110 - val_loss: 0.8504 - val_accuracy: 0.7364
# Epoch 38/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.2388 - accuracy: 0.9176 - val_loss: 0.8539 - val_accuracy: 0.7399
# Epoch 39/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.2381 - accuracy: 0.9189 - val_loss: 0.8652 - val_accuracy: 0.7428
# Epoch 40/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.2193 - accuracy: 0.9290 - val_loss: 0.8653 - val_accuracy: 0.7453
# Epoch 41/50
# 88/88 [==============================] - 1s 10ms/step - loss: 0.2095 - accuracy: 0.9304 - val_loss: 0.8798 - val_accuracy: 0.7474
# Epoch 42/50
# 88/88 [==============================] - 1s 9ms/step - loss: 0.2104 - accuracy: 0.9296 - val_loss: 0.8883 - val_accuracy: 0.7446
# Epoch 43/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.1907 - accuracy: 0.9382 - val_loss: 0.9189 - val_accuracy: 0.7364
# Epoch 44/50
# 88/88 [==============================] - 1s 7ms/step - loss: 0.1797 - accuracy: 0.9442 - val_loss: 0.9662 - val_accuracy: 0.7285
# Epoch 45/50
# 88/88 [==============================] - 1s 7ms/step - loss: 0.1747 - accuracy: 0.9446 - val_loss: 0.9479 - val_accuracy: 0.7392
# Epoch 46/50
# 88/88 [==============================] - 1s 7ms/step - loss: 0.1654 - accuracy: 0.9474 - val_loss: 0.9660 - val_accuracy: 0.7321
# Epoch 47/50
# 88/88 [==============================] - 1s 7ms/step - loss: 0.1520 - accuracy: 0.9556 - val_loss: 0.9967 - val_accuracy: 0.7349
# Epoch 48/50
# 88/88 [==============================] - 1s 7ms/step - loss: 0.1422 - accuracy: 0.9585 - val_loss: 1.0133 - val_accuracy: 0.7392
# Epoch 49/50
# 88/88 [==============================] - 1s 7ms/step - loss: 0.1366 - accuracy: 0.9593 - val_loss: 1.0102 - val_accuracy: 0.7349
# Epoch 50/50
# 88/88 [==============================] - 1s 8ms/step - loss: 0.1294 - accuracy: 0.9625 - val_loss: 1.0262 - val_accuracy: 0.7335

# %%
plot_accuracy_loss(history)

# %% [markdown]
# We should get approximately 0.844 accuracy (+0.1 accuracy) over the simple ConvNet.

# %%
test_loss = model2.evaluate(test_features, test_labels)
# Out:
# 94/94 [==============================] - 0s 4ms/step - loss: 1.0235 - accuracy: 0.7340

# %% [markdown]
# # Ensemble Neural Networks

# %%
np.random.seed(seed=1997)
# Number of estimators
n_estimators = 10
# Proporition of samples to use to train each training
max_samples = 0.8

max_samples *= n_train
max_samples = int(max_samples)

# %% [markdown]
# We define n_estimators Neural Networks.
#
# Each Neural Network will be trained on random subsets of the training dataset. Each subset contains max_samples samples.

# %%
models = list()
random = np.random.randint(50, 100, size = n_estimators)

for i in range(n_estimators):
    
    # Model
    model = tf.keras.Sequential([ tf.keras.layers.Flatten(input_shape = (x, y, z)),
                                # One layer with random size
                                    tf.keras.layers.Dense(random[i], activation=tf.nn.relu),
                                    tf.keras.layers.Dense(6, activation=tf.nn.softmax)
                                ])
    
    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
    
    # Store model
    models.append(model)

# %%
histories = []

for i in range(n_estimators):
    # Train each model on a bag of the training data
    train_idx = np.random.choice(len(train_features), size = max_samples)
    histories.append(models[i].fit(train_features[train_idx], train_labels[train_idx], batch_size=128, epochs=10, validation_split = 0.1))
# Out:
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 70us/sample - loss: 0.5195 - acc: 0.8076 - val_loss: 0.3429 - val_acc: 0.8878
# Epoch 2/10
# 10104/10104 [==============================] - 1s 58us/sample - loss: 0.2550 - acc: 0.9116 - val_loss: 0.3352 - val_acc: 0.8923
# Epoch 3/10
# 10104/10104 [==============================] - 0s 45us/sample - loss: 0.1892 - acc: 0.9349 - val_loss: 0.2939 - val_acc: 0.9074
# Epoch 4/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.1419 - acc: 0.9540 - val_loss: 0.2708 - val_acc: 0.9163
# Epoch 5/10
# 10104/10104 [==============================] - 0s 49us/sample - loss: 0.1097 - acc: 0.9671 - val_loss: 0.2762 - val_acc: 0.9110
# Epoch 6/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0933 - acc: 0.9721 - val_loss: 0.2816 - val_acc: 0.9225
# Epoch 7/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0664 - acc: 0.9841 - val_loss: 0.2760 - val_acc: 0.9261
# Epoch 8/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0515 - acc: 0.9890 - val_loss: 0.2726 - val_acc: 0.9314
# Epoch 9/10
# 10104/10104 [==============================] - 0s 48us/sample - loss: 0.0472 - acc: 0.9900 - val_loss: 0.3115 - val_acc: 0.9288
# Epoch 10/10
# 10104/10104 [==============================] - 0s 45us/sample - loss: 0.0375 - acc: 0.9924 - val_loss: 0.2820 - val_acc: 0.9297
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 63us/sample - loss: 0.4984 - acc: 0.8102 - val_loss: 0.3579 - val_acc: 0.8540
# Epoch 2/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.2489 - acc: 0.9150 - val_loss: 0.2696 - val_acc: 0.9065
# Epoch 3/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.1716 - acc: 0.9425 - val_loss: 0.2530 - val_acc: 0.9163
# Epoch 4/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.1284 - acc: 0.9610 - val_loss: 0.2602 - val_acc: 0.9110
# Epoch 5/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0966 - acc: 0.9728 - val_loss: 0.2189 - val_acc: 0.9252
# Epoch 6/10
# 10104/10104 [==============================] - 0s 40us/sample - loss: 0.0711 - acc: 0.9808 - val_loss: 0.2001 - val_acc: 0.9323
# Epoch 7/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.0525 - acc: 0.9885 - val_loss: 0.2035 - val_acc: 0.9314
# Epoch 8/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0455 - acc: 0.9904 - val_loss: 0.2384 - val_acc: 0.9288
# Epoch 9/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0347 - acc: 0.9920 - val_loss: 0.2220 - val_acc: 0.9270
# Epoch 10/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.0235 - acc: 0.9962 - val_loss: 0.2241 - val_acc: 0.9359
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 65us/sample - loss: 0.5163 - acc: 0.8127 - val_loss: 0.3729 - val_acc: 0.8780
# Epoch 2/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.2538 - acc: 0.9130 - val_loss: 0.2781 - val_acc: 0.9083
# Epoch 3/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.1920 - acc: 0.9369 - val_loss: 0.2456 - val_acc: 0.9261
# Epoch 4/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.1388 - acc: 0.9569 - val_loss: 0.2340 - val_acc: 0.9323
# Epoch 5/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.1098 - acc: 0.9682 - val_loss: 0.2425 - val_acc: 0.9279
# Epoch 6/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0851 - acc: 0.9756 - val_loss: 0.2329 - val_acc: 0.9359
# Epoch 7/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.0689 - acc: 0.9832 - val_loss: 0.2358 - val_acc: 0.9305
# Epoch 8/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.0569 - acc: 0.9855 - val_loss: 0.2160 - val_acc: 0.9412
# Epoch 9/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0378 - acc: 0.9940 - val_loss: 0.2181 - val_acc: 0.9439
# Epoch 10/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.0329 - acc: 0.9957 - val_loss: 0.2233 - val_acc: 0.9439
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 67us/sample - loss: 0.5010 - acc: 0.8169 - val_loss: 0.3431 - val_acc: 0.8736
# Epoch 2/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.2584 - acc: 0.9104 - val_loss: 0.2799 - val_acc: 0.8958
# Epoch 3/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.1827 - acc: 0.9405 - val_loss: 0.2365 - val_acc: 0.9145
# Epoch 4/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.1352 - acc: 0.9604 - val_loss: 0.2441 - val_acc: 0.9118
# Epoch 5/10
# 10104/10104 [==============================] - 0s 40us/sample - loss: 0.1089 - acc: 0.9689 - val_loss: 0.2499 - val_acc: 0.9118
# Epoch 6/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.0863 - acc: 0.9777 - val_loss: 0.2102 - val_acc: 0.9261
# Epoch 7/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0684 - acc: 0.9842 - val_loss: 0.2053 - val_acc: 0.9350
# Epoch 8/10
# 10104/10104 [==============================] - 0s 40us/sample - loss: 0.0581 - acc: 0.9875 - val_loss: 0.2527 - val_acc: 0.9172
# Epoch 9/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0475 - acc: 0.9887 - val_loss: 0.2179 - val_acc: 0.9332
# Epoch 10/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0344 - acc: 0.9948 - val_loss: 0.2294 - val_acc: 0.9314
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 69us/sample - loss: 0.4995 - acc: 0.8107 - val_loss: 0.3211 - val_acc: 0.8985
# Epoch 2/10
# 10104/10104 [==============================] - 0s 46us/sample - loss: 0.2529 - acc: 0.9091 - val_loss: 0.2995 - val_acc: 0.8994
# Epoch 3/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.1822 - acc: 0.9370 - val_loss: 0.2481 - val_acc: 0.9145
# Epoch 4/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.1400 - acc: 0.9567 - val_loss: 0.2216 - val_acc: 0.9252
# Epoch 5/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.1039 - acc: 0.9707 - val_loss: 0.2207 - val_acc: 0.9305
# Epoch 6/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.0941 - acc: 0.9706 - val_loss: 0.2097 - val_acc: 0.9332
# Epoch 7/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.0720 - acc: 0.9807 - val_loss: 0.2234 - val_acc: 0.9332
# Epoch 8/10
# 10104/10104 [==============================] - 0s 45us/sample - loss: 0.0512 - acc: 0.9876 - val_loss: 0.2056 - val_acc: 0.9394
# Epoch 9/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0451 - acc: 0.9900 - val_loss: 0.2396 - val_acc: 0.9297
# Epoch 10/10
# 10104/10104 [==============================] - 0s 45us/sample - loss: 0.0362 - acc: 0.9923 - val_loss: 0.2104 - val_acc: 0.9475
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 69us/sample - loss: 0.5115 - acc: 0.8069 - val_loss: 0.3113 - val_acc: 0.8914
# Epoch 2/10
# 10104/10104 [==============================] - 0s 37us/sample - loss: 0.2709 - acc: 0.9025 - val_loss: 0.2757 - val_acc: 0.9020
# Epoch 3/10
# 10104/10104 [==============================] - 0s 40us/sample - loss: 0.1898 - acc: 0.9389 - val_loss: 0.2553 - val_acc: 0.9038
# Epoch 4/10
# 10104/10104 [==============================] - 0s 40us/sample - loss: 0.1435 - acc: 0.9554 - val_loss: 0.2421 - val_acc: 0.9092
# Epoch 5/10
# 10104/10104 [==============================] - 0s 40us/sample - loss: 0.1094 - acc: 0.9695 - val_loss: 0.2012 - val_acc: 0.9305
# Epoch 6/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0836 - acc: 0.9790 - val_loss: 0.2111 - val_acc: 0.9225
# Epoch 7/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.0681 - acc: 0.9830 - val_loss: 0.2434 - val_acc: 0.9172
# Epoch 8/10
# 10104/10104 [==============================] - 1s 50us/sample - loss: 0.0544 - acc: 0.9871 - val_loss: 0.1970 - val_acc: 0.9341
# Epoch 9/10
# 10104/10104 [==============================] - 0s 49us/sample - loss: 0.0461 - acc: 0.9893 - val_loss: 0.1974 - val_acc: 0.9350
# Epoch 10/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.0370 - acc: 0.9917 - val_loss: 0.2052 - val_acc: 0.9332
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 73us/sample - loss: 0.4543 - acc: 0.8367 - val_loss: 0.3403 - val_acc: 0.8575
# Epoch 2/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.2329 - acc: 0.9196 - val_loss: 0.2773 - val_acc: 0.8967
# Epoch 3/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.1685 - acc: 0.9455 - val_loss: 0.2534 - val_acc: 0.9154
# Epoch 4/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.1260 - acc: 0.9602 - val_loss: 0.2471 - val_acc: 0.9136
# Epoch 5/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0923 - acc: 0.9730 - val_loss: 0.2150 - val_acc: 0.9252
# Epoch 6/10
# 10104/10104 [==============================] - 0s 40us/sample - loss: 0.0765 - acc: 0.9778 - val_loss: 0.2400 - val_acc: 0.9118
# Epoch 7/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.0571 - acc: 0.9853 - val_loss: 0.2214 - val_acc: 0.9297
# Epoch 8/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.0432 - acc: 0.9905 - val_loss: 0.2155 - val_acc: 0.9377
# Epoch 9/10
# 10104/10104 [==============================] - 1s 50us/sample - loss: 0.0328 - acc: 0.9943 - val_loss: 0.2178 - val_acc: 0.9403
# Epoch 10/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.0262 - acc: 0.9951 - val_loss: 0.2331 - val_acc: 0.9377
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 70us/sample - loss: 0.5055 - acc: 0.8145 - val_loss: 0.2760 - val_acc: 0.9163
# Epoch 2/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.2630 - acc: 0.9070 - val_loss: 0.3078 - val_acc: 0.8789
# Epoch 3/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.1917 - acc: 0.9356 - val_loss: 0.2116 - val_acc: 0.9341
# Epoch 4/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.1392 - acc: 0.9566 - val_loss: 0.1892 - val_acc: 0.9394
# Epoch 5/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.1056 - acc: 0.9693 - val_loss: 0.1751 - val_acc: 0.9510
# Epoch 6/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0823 - acc: 0.9793 - val_loss: 0.2165 - val_acc: 0.9314
# Epoch 7/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.0697 - acc: 0.9807 - val_loss: 0.1849 - val_acc: 0.9475
# Epoch 8/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.0685 - acc: 0.9789 - val_loss: 0.1906 - val_acc: 0.9403
# Epoch 9/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0394 - acc: 0.9932 - val_loss: 0.1808 - val_acc: 0.9475
# Epoch 10/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0330 - acc: 0.9941 - val_loss: 0.1791 - val_acc: 0.9519
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 74us/sample - loss: 0.5066 - acc: 0.7990 - val_loss: 0.3342 - val_acc: 0.8771
# Epoch 2/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.2497 - acc: 0.9141 - val_loss: 0.2997 - val_acc: 0.8931
# Epoch 3/10
# 10104/10104 [==============================] - 0s 41us/sample - loss: 0.1846 - acc: 0.9402 - val_loss: 0.2725 - val_acc: 0.9145
# Epoch 4/10
# 10104/10104 [==============================] - 0s 42us/sample - loss: 0.1334 - acc: 0.9612 - val_loss: 0.2632 - val_acc: 0.9172
# Epoch 5/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.1091 - acc: 0.9676 - val_loss: 0.2599 - val_acc: 0.9243
# Epoch 6/10
# 10104/10104 [==============================] - 0s 45us/sample - loss: 0.0799 - acc: 0.9799 - val_loss: 0.2586 - val_acc: 0.9225
# Epoch 7/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0626 - acc: 0.9853 - val_loss: 0.2680 - val_acc: 0.9252
# Epoch 8/10
# 10104/10104 [==============================] - 0s 48us/sample - loss: 0.0513 - acc: 0.9887 - val_loss: 0.2673 - val_acc: 0.9279
# Epoch 9/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0375 - acc: 0.9928 - val_loss: 0.2581 - val_acc: 0.9368
# Epoch 10/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0310 - acc: 0.9945 - val_loss: 0.2643 - val_acc: 0.9350
# Train on 10104 samples, validate on 1123 samples
# Epoch 1/10
# 10104/10104 [==============================] - 1s 75us/sample - loss: 0.5397 - acc: 0.8012 - val_loss: 0.3338 - val_acc: 0.8878
# Epoch 2/10
# 10104/10104 [==============================] - 1s 60us/sample - loss: 0.2670 - acc: 0.9084 - val_loss: 0.2764 - val_acc: 0.9012
# Epoch 3/10
# 10104/10104 [==============================] - 1s 52us/sample - loss: 0.1967 - acc: 0.9352 - val_loss: 0.2553 - val_acc: 0.9136
# Epoch 4/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.1523 - acc: 0.9522 - val_loss: 0.2576 - val_acc: 0.9225
# Epoch 5/10
# 10104/10104 [==============================] - 0s 46us/sample - loss: 0.1227 - acc: 0.9635 - val_loss: 0.2191 - val_acc: 0.9332
# Epoch 6/10
# 10104/10104 [==============================] - 0s 40us/sample - loss: 0.1012 - acc: 0.9695 - val_loss: 0.2269 - val_acc: 0.9412
# Epoch 7/10
# 10104/10104 [==============================] - 1s 61us/sample - loss: 0.0764 - acc: 0.9796 - val_loss: 0.2104 - val_acc: 0.9421
# Epoch 8/10
# 10104/10104 [==============================] - 0s 43us/sample - loss: 0.0609 - acc: 0.9860 - val_loss: 0.2150 - val_acc: 0.9332
# Epoch 9/10
# 10104/10104 [==============================] - 0s 49us/sample - loss: 0.0520 - acc: 0.9874 - val_loss: 0.2338 - val_acc: 0.9297
# Epoch 10/10
# 10104/10104 [==============================] - 0s 44us/sample - loss: 0.0391 - acc: 0.9925 - val_loss: 0.2114 - val_acc: 0.9403

# %% [markdown]
# We aggregate each model individual predictions to form a final prediction.

# %%
predictions = []
for i in range(n_estimators):
    predictions.append(models[i].predict(test_features))
    
predictions = np.array(predictions)
predictions = predictions.sum(axis = 0)
pred_labels = predictions.argmax(axis=1)

# %% [markdown]
# We should improve our result as we have a lower variance.

# %%
from sklearn.metrics import accuracy_score
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))
# Out:
# Accuracy : 0.889

# %% [markdown]
# # Fine Tuning VGG ImageNet

# %%
from keras.models import Model

model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=model.inputs, outputs=model.layers[-5].output)

# %%
train_features = model.predict(train_images)
test_features = model.predict(test_images)

# %%
from keras.layers import Input, Dense, Conv2D, Activation , MaxPooling2D, Flatten

model2 = VGG16(weights='imagenet', include_top=False)

input_shape = model2.layers[-4].get_input_shape_at(0) # get the input shape of desired layer
layer_input = Input(shape = (9, 9, 512)) # a new input tensor to be able to feed the desired layer
# https://stackoverflow.com/questions/52800025/keras-give-input-to-intermediate-layer-and-get-final-output

x = layer_input
for layer in model2.layers[-4::1]:
    x = layer(x)
    
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(100,activation='relu')(x)
x = Dense(6,activation='softmax')(x)

# create the model
new_model = Model(layer_input, x)

# %%
new_model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
new_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        multiple                  2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        multiple                  2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        multiple                  2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   multiple                  0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 2, 2, 64)          294976
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               6500
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 606
# =================================================================
# Total params: 7,381,506
# Trainable params: 7,381,506
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = new_model.fit(train_features, train_labels, batch_size=128, epochs=10, validation_split = 0.2)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 11227 samples, validate on 2807 samples
# Epoch 1/10
# 11227/11227 [==============================] - 6s 532us/step - loss: 0.5956 - acc: 0.7682 - val_loss: 0.4633 - val_acc: 0.8322
# Epoch 2/10
# 11227/11227 [==============================] - 4s 397us/step - loss: 0.3020 - acc: 0.8912 - val_loss: 0.3113 - val_acc: 0.8995
# Epoch 3/10
# 11227/11227 [==============================] - 4s 388us/step - loss: 0.2298 - acc: 0.9160 - val_loss: 0.4231 - val_acc: 0.8703
# Epoch 4/10
# 11227/11227 [==============================] - 4s 390us/step - loss: 0.1940 - acc: 0.9303 - val_loss: 0.3473 - val_acc: 0.8824
# Epoch 5/10
# 11227/11227 [==============================] - 4s 385us/step - loss: 0.1563 - acc: 0.9440 - val_loss: 0.3840 - val_acc: 0.8917
# Epoch 6/10
# 11227/11227 [==============================] - 4s 399us/step - loss: 0.1249 - acc: 0.9563 - val_loss: 0.3742 - val_acc: 0.8928
# Epoch 7/10
# 11227/11227 [==============================] - 4s 396us/step - loss: 0.1071 - acc: 0.9637 - val_loss: 0.3833 - val_acc: 0.9070
# Epoch 8/10
# 11227/11227 [==============================] - 4s 392us/step - loss: 0.1128 - acc: 0.9605 - val_loss: 0.3641 - val_acc: 0.8974
# Epoch 9/10
# 11227/11227 [==============================] - 4s 396us/step - loss: 0.0675 - acc: 0.9757 - val_loss: 0.5239 - val_acc: 0.8942
# Epoch 10/10
# 11227/11227 [==============================] - 4s 390us/step - loss: 0.0706 - acc: 0.9757 - val_loss: 0.4649 - val_acc: 0.9038

# %%
plot_accuracy_loss(history)

# %%
from sklearn.metrics import accuracy_score

predictions = new_model.predict(test_features)    
pred_labels = np.argmax(predictions, axis = 1)
print("Accuracy : {}".format(accuracy_score(test_labels, pred_labels)))
# Out:
# Accuracy : 0.8933333333333333
